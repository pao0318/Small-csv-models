# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
# Technically not necessary in newest versions of jupyter
# %matplotlib inline

# %%
df = pd.read_csv('socialage.csv')

# %%
df
# Out:
#         Unnamed: 0    userId  tier  gender  following_rate  followers_avg_age  \
# 0           265153  48958844     2       1        0.000000              0.000
# 1           405231  51100441     2       2        0.000000              0.000
# 2            57867   6887426     2       1        0.000000              0.000
# 3           272618  50742404     2       1        0.000000              0.000
# 4           251123  45589200     2       2        0.000000              0.000
# ...            ...       ...   ...     ...             ...                ...
# 488872      535266  38983571     2       2        0.000000              0.000
# 488873       36706  53264639     1       1        0.017241              0.000
# 488874       31570  44693578     1       1        0.229508              1.625
# 488875      239209  42760145     2       1        0.000000              0.000
# 488876      238035  42482997     2       1        0.000000              0.000
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# userId                             0
# tier                               0
# gender                             0
# following_rate                     0
# followers_avg_age                  0
# following_avg_age                  0
# max_repetitive_punc                0
# num_of_hashtags_per_action         0
# emoji_count_per_action             0
# punctuations_per_action            0
# number_of_words_per_action         0
# avgCompletion                      0
# avgTimeSpent                       0
# avgDuration                        0
# avgComments                        0
# creations                          0
# content_views                      0
# num_of_comments                    0
# weekends_trails_watched_per_day    0
# weekdays_trails_watched_per_day    0
# slot1_trails_watched_per_day       0
# slot2_trails_watched_per_day       0
# slot3_trails_watched_per_day       0
# slot4_trails_watched_per_day       0
# ...

# %%
df.corr()
# Out:
#                                  Unnamed: 0    userId      tier    gender  \
# Unnamed: 0                         1.000000  0.211034  0.233388 -0.021786
# userId                             0.211034  1.000000  0.042470  0.074968
# tier                               0.233388  0.042470  1.000000 -0.016541
# gender                            -0.021786  0.074968 -0.016541  1.000000
# following_rate                    -0.015027 -0.001291 -0.018307 -0.006732
# followers_avg_age                 -0.014233 -0.193482 -0.083842 -0.030644
# following_avg_age                 -0.014613 -0.209797 -0.081714 -0.038668
# max_repetitive_punc               -0.009107 -0.052181 -0.056094  0.026174
# num_of_hashtags_per_action         0.001472 -0.009496 -0.003478 -0.000551
# emoji_count_per_action             0.005830 -0.008383  0.000556  0.016659
# punctuations_per_action            0.007962 -0.026391 -0.001514  0.008254
# number_of_words_per_action         0.009675 -0.197195 -0.053159 -0.002821
# ...

# %%
# df1=df1.drop(['tier','gender','userId'],axis=1)
df=df.drop(['tier','num_of_hashtags_per_action','emoji_count_per_action'],axis=1)

# %%
# from imblearn.over_sampling import RandomOverSampler
# os=RandomOverSampler()

# s1=df[df['age_group']==1]
# s2=df[df['age_group']==2]

# s3=df[df['age_group']==3]
# s4=df[df['age_group']==4]
# sshit=[s2,s3,s4]
# s,ss=os.fit_sample(s1,s2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-e1c82cb2b3e1> in <module>
# ----> 1 from imblearn.over_sampling import RandomOverSampler
#       2 os=RandomOverSampler()
#       3 s1=df[df['age_group']==1]
#       4 s2=df[df['age_group']==2]
#       5
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
# Out:
#         Unnamed: 0    userId  gender  following_rate  followers_avg_age  \
# 7            18705  33815341       2        0.000000           0.000000
# 16           16863  32554791       1       19.640625           1.921013
# 24           26438  34998606       1        1.285714           2.065217
# 26          445058  44850800       1        0.016393           0.000000
# 28          162644  47380405       1        0.016529           1.000000
# ...            ...       ...     ...             ...                ...
# 488849       36310  45429109       1        0.040984           4.000000
# 488851       16045  32050102       2        0.007812           1.000000
# 488852      467108  56145489       1        0.194444           1.833333
# 488865      538317  37562999       1        0.008000           1.000000
# 488870       26772  34997641       1        0.103175           1.875000
#
#         following_avg_age  max_repetitive_punc  punctuations_per_action  \
# ...

# %%
sns.countplot(x='age_group',data=df)
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='count'>

# %%
df['avgt2'].describe()
# Out:
# count    488877.000000
# mean        164.765782
# std         981.988886
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         178.666667
# max       39304.000000
# Name: avgt2, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('age_group',axis=1).values
y = df['age_group'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
predictions = model.predict_classes(X_test)
print(classification_report(y_test,predictions))

# %%
from xgboost import XGBClassifier
model6 = XGBClassifier()
model6.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import classification_report,confusion_matrix
prediction6 = model6.predict(X_test)
print(classification_report(y_test,prediction6))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.93      0.93     61596
#            2       0.58      0.74      0.65     12002
#            3       0.52      0.64      0.57     12020
#            4       0.68      0.33      0.45     12158
#
#     accuracy                           0.80     97776
#    macro avg       0.68      0.66      0.65     97776
# weighted avg       0.80      0.80      0.79     97776

# %%
from sklearn.ensemble import RandomForestClassifier
model5 = RandomForestClassifier()
model5.fit(X_train,y_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix
prediction5 = model5.predict(X_test)
print(classification_report(y_test,prediction5))

# %%
df1

# %%
df1 = scaler.transform(df1)
test_pred = model5.predict(df1)

# %%
test_pred

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Coding/cascade/test_age_dataset.csv')

# %%
df2['Price'] = test_pred

# %%
df2['Price'].describe()

# %%
df2 = df2['Price'].values

# %%
df2 = pd.Series(df2)

# %%
df2.to_csv (r'/content/drive/MyDrive/Coding/cascade/export_dataframe3.csv', index = False, header=True)

# %%
df2
